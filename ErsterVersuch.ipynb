# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaHrmiz/ErsterVersuch/blob/main/ErsterVersuch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from google.colab import drive
import pandas as pd
import requests
from io import StringIO

# %%
url = 'https://info.gesundheitsministerium.gv.at/data/timeline-faelle-bundeslaender.csv'
df = pd.read_csv(url, sep=';')

# %%
df.head()
# Out:
#                        Datum  BundeslandID              Name  \
# 0  2021-03-01T09:30:00+01:00             1        Burgenland
# 1  2021-03-01T09:30:00+01:00             2           Kärnten
# 2  2021-03-01T09:30:00+01:00             3  Niederösterreich
# 3  2021-03-01T09:30:00+01:00             4    Oberösterreich
# 4  2021-03-01T09:30:00+01:00             5          Salzburg
#
#    BestaetigteFaelleBundeslaender  Todesfaelle  Genesen  Hospitalisierung  \
# 0                           12657          239    11701                43
# 1                           29225          683    27316                96
# 2                           74538         1350    67900               349
# 3                           86409         1515    82567               120
# 4                           37327          493    35318                71
#
#    Intensivstation  Testungen  TestungenPCR  TestungenAntigen
# 0               10     638575        155435            483140
# ...
